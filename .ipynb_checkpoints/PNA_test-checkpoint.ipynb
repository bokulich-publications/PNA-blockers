# %% [markdown]
# # Testing the efficiency of the PNA blockers
#
# note. the pos ctrl did not have any chloroplast / mitochondria contamination so I excluded these samples here
#
# ## 0. Setup

# %%
#!mkdir /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/PNA-test

# %%
wd = '/home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/PNA-test'
# %cd $wd
# Out:
# /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/PNA-test

# %%
import os
import json
import pandas as pd
from bs4 import BeautifulSoup
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
import matplotlib.lines as mlines

# statistics 
from scipy.spatial.distance import pdist, squareform
from skbio.stats.distance import permanova
from skbio.stats.distance import DistanceMatrix
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# QIIME 2
import qiime2 as q2
from qiime2 import (Artifact, Metadata)
from qiime2.plugins.feature_table.methods import filter_samples, group
import qiime2.plugins.taxa.actions as taxa_actions
from qiime2.plugins import (feature_table as qft,
                            diversity as q2d,
                            taxa as q2t,
                            composition as comp)
from qiime2.plugins.diversity.visualizers import alpha_group_significance
from qiime2.plugins.diversity.methods import procrustes_analysis
from qiime2.plugins.emperor.visualizers import procrustes_plot
from qiime2.plugins.composition.methods import add_pseudocount


from qiime2 import Visualization
# %matplotlib inline

# %%
# Load artifacts
# `FeatureTable[Frequency]` filtered 
table_bac = q2.Artifact.load('/home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/decontam-table.qza')

# load metadata 
metadata = '/home/lfloerl/RxCS/Metadata/16S_PNA-test.csv'
md = Metadata.load(metadata)

# our own fragment insertion tree 
mafft_tree = '/home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/rooted-tree.qza'
tree = q2.Artifact.load(mafft_tree)

# taxonomy
taxonomy = q2.Artifact.load('/home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/taxonomy.qza')

# %% [markdown]
# <hr>
#
# # 1. Show reduction of host contamination
#
# ## Filter the table to only contain the PNA test samples

# %%
# filter out contaminations and only keep taxa classified to phylum level 
exclude_terms = 'Alcaligenaceae,Caulobacteraceae,Comamonadaceae,Eukaryota,Pedobacter'
taxa_filtered_table, = q2t.actions.filter_table(
                                table=table_bac, 
                                taxonomy=taxonomy,
                                include='p__',
                                exclude=exclude_terms)

# filter table to only contain the PNA test samples 
table_PNAs, = filter_samples(table=taxa_filtered_table, 
                            metadata=md)
table_PNAs.save('PNA-table.qza')
# Out:
# 'PNA-table.qza'

# %%
# !qiime feature-table summarize --i-table PNA-table.qza --o-visualization PNA-table.qzv
# Out:
# Saved Visualization to: PNA-table.qzv

# %%
Visualization.load('PNA-table.qzv')
# Out:
# <visualization: Visualization uuid: d410fea3-194d-40bb-854c-46ec35af7087>

# %% [markdown]
# ## Taxa barplot of all samples

# %%
taxa_bar_plots_viz, = taxa_actions.barplot(
    table=table_PNAs,
    taxonomy=taxonomy,
    metadata=md
)
taxa_bar_plots_viz.save('taxa_barplot.qzv')
# Out:
# 'taxa_barplot.qzv'

# %%
Visualization.load('taxa_barplot.qzv')
# Out:
# <visualization: Visualization uuid: c1cce318-746d-4214-9e6f-ec3bc002b5dc>

# %% [markdown]
# ### Download the csv at level 5 and work with this one

# %%
taxa_level5 = pd.read_csv('level-5(4).csv')

# Drop the pos ctrl
df_filtered = taxa_level5[~taxa_level5['Sample'].str.contains('pos', case=False, na=False)]
taxa_level5 = df_filtered

# %%
# Identify analysis columns
analysis_columns = [col for col in taxa_level5.columns if col.startswith('d__Bacteria')]

# Normalize the values in the analysis columns to percentages
taxa_level5[analysis_columns] = taxa_level5[analysis_columns].div(taxa_level5[analysis_columns].sum(axis=1), axis=0) * 100

# Sort the DataFrame by 'mPNA' and 'pPNA'
df_sorted = taxa_level5.sort_values(by=['mPNA', 'pPNA'])

# Define colors
colors = []
for col in analysis_columns:
    if 'Chloroplast' in col:
        colors.append('green')
    elif 'Mitochondria' in col:
        colors.append('purple')
    else:
        colors.append('grey')

# %% [markdown]
# ## Grouped Plot

# %%
# specify columns we want to keep
additional_cols = ['PNA_composition', 'mPNA','pPNA', 'PNA_mix', 'Sample_ID']
cols_to_keep = additional_cols + analysis_columns

# subset to only keep interesting cols 
df_grouped = taxa_level5[cols_to_keep]

# cols_to_group: those NOT containing 'Chloroplast' or 'Mitochondria' 
cols_to_group = [col for col in analysis_columns if 'Chloroplast' not in col and 'Mitochondria' not in col]

# Sum the values of the filtered columns for each row and drop them 
df_grouped['Other_bacteria'] = df_grouped[cols_to_group].sum(axis=1)
df_grouped.drop(columns=cols_to_group, inplace=True)
df_grouped.rename(columns={'d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rickettsiales;f__Mitochondria':'Mitochondria', 'd__Bacteria;p__Cyanobacteria;c__Cyanobacteriia;o__Chloroplast;f__Chloroplast' : 'Chloroplast'}, inplace=True, errors='raise')
# Out:
# /scratch/lfloerl/tmpdata/ipykernel_261076/1004534357.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_grouped['Other_bacteria'] = df_grouped[cols_to_group].sum(axis=1)
# /scratch/lfloerl/tmpdata/ipykernel_261076/1004534357.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_grouped.drop(columns=cols_to_group, inplace=True)
# /scratch/lfloerl/tmpdata/ipykernel_261076/1004534357.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_grouped.rename(columns={'d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rickettsiales;f__Mitochondria':'Mitochondria', 'd__Bacteria;p__Cyanobacteria;c__Cyanobacteriia;o__Chloroplast;f__Chloroplast' : 'Chloroplast'}, inplace=True, errors='raise')

# %%
# Columns to convert to relative frequencies
columns_to_convert = ['Mitochondria', 'Chloroplast', 'Other_bacteria']

# Calculate the sum of the specified columns for each row
row_sums = df_grouped[columns_to_convert].sum(axis=1)

# Convert the values to relative frequencies (percentages)
df_grouped[columns_to_convert] = df_grouped[columns_to_convert].div(row_sums, axis=0) * 100
# Out:
# /scratch/lfloerl/tmpdata/ipykernel_261076/3918554262.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_grouped[columns_to_convert] = df_grouped[columns_to_convert].div(row_sums, axis=0) * 100

# %% [markdown]
# ### pPNA

# %%
pPNA = df_grouped[df_grouped['PNA_mix'].isin(['pPNA','None'])]
pPNA.sort_values(by=['pPNA'], inplace=True)
# Out:
# /scratch/lfloerl/tmpdata/ipykernel_261076/2863076037.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pPNA.sort_values(by=['pPNA'], inplace=True)

# %%
# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# CHLOROPLASTS 
# Box plot with transparency
box_plot = sns.boxplot(ax=axes[0], x='pPNA', y='Chloroplast', data=pPNA, fliersize=0, boxprops=dict(alpha=0.5), palette='Blues')
# Overlay strip plot
strip_plot = sns.stripplot(ax=axes[0], x='pPNA', y='Chloroplast', data=pPNA, jitter=False, color='navy', size=3)

# Calculate and annotate median values for Chloroplast
medians_chloroplast = pPNA.groupby('pPNA')['Chloroplast'].median()
for index, value in enumerate(medians_chloroplast):
    axes[0].text(index, value + 0.5, f'{value:.2f}', ha='center', va='bottom', color='black')

axes[0].set_xlabel('pPNA concentrations [µM]')
axes[0].set_ylabel('Percentage of Chloroplast Contamination')


# MITOCHONDRIA  
# Box plot with transparency
box_plot = sns.boxplot(ax=axes[1], x='pPNA', y='Mitochondria', data=pPNA, fliersize=0, boxprops=dict(alpha=0.5), palette='Blues')
# Overlay strip plot
strip_plot = sns.stripplot(ax=axes[1], x='pPNA', y='Mitochondria', data=pPNA, jitter=False, color='navy', size=3)

# Calculate and annotate median values for Chloroplast
medians_chloroplast = pPNA.groupby('pPNA')['Mitochondria'].median()
for index, value in enumerate(medians_chloroplast):
    axes[1].text(index, value + 0.5, f'{value:.2f}', ha='center', va='bottom', color='black')

axes[1].set_xlabel('pPNA concentrations [µM]')
axes[1].set_ylabel('Percentage of Mitochondria Contamination')


# Show the plot
plt.show()

# %% [markdown]
# ### mPNA

# %%
mPNA = df_grouped[df_grouped['PNA_mix'].isin(['mPNA','None'])]
mPNA.sort_values(by=['mPNA'], inplace=True)
# Out:
# /scratch/lfloerl/tmpdata/ipykernel_261076/2804856077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mPNA.sort_values(by=['mPNA'], inplace=True)

# %%
# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# CHLOROPLASTS 
# Box plot with transparency
box_plot = sns.boxplot(ax=axes[0], x='mPNA', y='Chloroplast', data=mPNA, fliersize=0, boxprops=dict(alpha=0.5), palette='Blues')
# Overlay strip plot
strip_plot = sns.stripplot(ax=axes[0], x='mPNA', y='Chloroplast', data=mPNA, jitter=False, color='navy', size=3)

# Calculate and annotate median values for Chloroplast
medians_chloroplast = mPNA.groupby('mPNA')['Chloroplast'].median()
for index, value in enumerate(medians_chloroplast):
    axes[0].text(index, value + 0.5, f'{value:.2f}', ha='center', va='bottom', color='black')

axes[0].set_xlabel('mPNA concentrations [µM]')
axes[0].set_ylabel('Percentage of Chloroplast Contamination')


# MITOCHONDRIA  
# Box plot with transparency
box_plot = sns.boxplot(ax=axes[1], x='mPNA', y='Mitochondria', data=mPNA, fliersize=0, boxprops=dict(alpha=0.5), palette='Blues')
# Overlay strip plot
strip_plot = sns.stripplot(ax=axes[1], x='mPNA', y='Mitochondria', data=mPNA, jitter=False, color='navy', size=3)

# Calculate and annotate median values for Chloroplast
medians_chloroplast = mPNA.groupby('mPNA')['Mitochondria'].median()
for index, value in enumerate(medians_chloroplast):
    axes[1].text(index, value + 0.5, f'{value:.2f}', ha='center', va='bottom', color='black')

axes[1].set_xlabel('mPNA concentrations [µM]')
axes[1].set_ylabel('Percentage of Mitochondria Contamination')


# Show the plot
plt.show()

# %% [markdown]
# ### pPNA + mPNA

# %%
mpPNA = df_grouped[df_grouped['PNA_mix'].isin(['mPNA+pPNA','None'])]
mpPNA.sort_values(by=['mPNA'], inplace=True)
# Out:
# /scratch/lfloerl/tmpdata/ipykernel_261076/103832724.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mpPNA.sort_values(by=['mPNA'], inplace=True)

# %%
# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# CHLOROPLASTS 
# Box plot with transparency
box_plot = sns.boxplot(ax=axes[0], x='mPNA', y='Chloroplast', data=mpPNA, fliersize=0, boxprops=dict(alpha=0.5), palette='Blues')
# Overlay strip plot
strip_plot = sns.stripplot(ax=axes[0], x='mPNA', y='Chloroplast', data=mpPNA, jitter=False, color='navy', size=3)

# Calculate and annotate median values for Chloroplast
medians_chloroplast = mpPNA.groupby('mPNA')['Chloroplast'].median()
for index, value in enumerate(medians_chloroplast):
    axes[0].text(index, value + 0.5, f'{value:.2f}', ha='center', va='bottom', color='black')

axes[0].set_xlabel('mPNA+pPNA concentrations [µM]')
axes[0].set_ylabel('Percentage of Chloroplast Contamination')


# MITOCHONDRIA  
# Box plot with transparency
box_plot = sns.boxplot(ax=axes[1], x='mPNA', y='Mitochondria', data=mpPNA, fliersize=0, boxprops=dict(alpha=0.5), palette='Blues')
# Overlay strip plot
strip_plot = sns.stripplot(ax=axes[1], x='mPNA', y='Mitochondria', data=mpPNA, jitter=False, color='navy', size=3)

# Calculate and annotate median values for Chloroplast
medians_chloroplast = mpPNA.groupby('mPNA')['Mitochondria'].median()
for index, value in enumerate(medians_chloroplast):
    axes[1].text(index, value + 0.5, f'{value:.2f}', ha='center', va='bottom', color='black')

axes[1].set_xlabel('mPNA+pPNA concentrations [µM]')
axes[1].set_ylabel('Percentage of Mitochondria Contamination')


#plt.savefig('box_plots.png', dpi=200)
# Show the plot
plt.show()

# %% [markdown]
# ## Line plots

# %%
medians_chloroplast_mpPNA = mpPNA.groupby('mPNA')['Chloroplast'].median()
medians_chloroplast_pPNA = pPNA.groupby('pPNA')['Chloroplast'].median()
medians_chloroplast_mPNA = mPNA.groupby('mPNA')['Chloroplast'].median()

medians_chloroplast = pd.concat([medians_chloroplast_mpPNA, medians_chloroplast_pPNA, medians_chloroplast_mPNA], axis=1)
medians_chloroplast.columns = ['mpPNA', 'pPNA','mPNA']
medians_chloroplast
# Out:
#           mpPNA       pPNA       mPNA
# 0.00  93.696367  93.696367  93.696367
# 0.25  50.158386  18.714756  94.518700
# 0.50  29.450056  19.226915  94.044160
# 0.75  33.957219  28.612835  94.814815
# 1.00  28.832503  21.992592  94.620779
# 1.25  32.235294  20.968866  94.171348

# %%
medians_mitochondria_mpPNA = mpPNA.groupby('mPNA')['Mitochondria'].median()
medians_mitochondria_pPNA = pPNA.groupby('pPNA')['Mitochondria'].median()
medians_mitochondria_mPNA = mPNA.groupby('mPNA')['Mitochondria'].median()

medians_mitochondria = pd.concat([medians_mitochondria_mpPNA, medians_mitochondria_pPNA, medians_mitochondria_mPNA], axis=1)
medians_mitochondria.columns = ['mpPNA', 'pPNA','mPNA']
medians_mitochondria
# Out:
#           mpPNA       pPNA      mPNA
# 0.00   4.301473   4.301473  4.301473
# 0.25  18.552036  46.795174  0.339831
# 0.50  12.074774  55.206731  0.305381
# 0.75  25.302612  56.801854  0.148303
# 1.00  36.158702  34.375000  0.171270
# 1.25  18.602033  45.744681  0.351921

# %%
# Calculate median Mitochondria and Chloroplast for mpPNA
medians_mitochondria_mpPNA = mpPNA.groupby('pPNA')['Mitochondria'].median()
medians_chloroplast_mpPNA = mpPNA.groupby('pPNA')['Chloroplast'].median()

# Combine into a DataFrame
medians_combined_mpPNA = pd.concat([medians_mitochondria_mpPNA, medians_chloroplast_mpPNA], axis=1)
medians_combined_mpPNA.columns = ['Mitochondria', 'Chloroplast']

# Display the result
medians_combined_mpPNA
# Out:
#       Mitochondria  Chloroplast
# pPNA
# 0.00      4.301473    93.696367
# 0.25     18.552036    50.158386
# 0.50     12.074774    29.450056
# 0.75     25.302612    33.957219
# 1.00     36.158702    28.832503
# 1.25     18.602033    32.235294

# %%
# Lineplots with confidence intervals
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Chloroplast plot
#sns.lineplot(ax=axes[0], data=mpPNA, x='mPNA', y='Chloroplast', errorbar='sd', estimator='median', color='#440154FF', lw=2, label='m+pPNA')
sns.lineplot(ax=axes[0], data=pPNA, x='pPNA', y='Chloroplast', errorbar='sd', estimator='median', color='#56C667FF', lw=2, label='pPNA')
axes[0].set_xlabel('Concentrations [µM]')
axes[0].set_ylabel('Percentage of Chloroplast Contamination')

# Mitochondria plot
#sns.lineplot(ax=axes[1], data=mpPNA, x='mPNA', y='Mitochondria', errorbar='sd', estimator='median', color='#440154FF', lw=2, label='m+pPNA')
sns.lineplot(ax=axes[1], data=mPNA, x='mPNA', y='Mitochondria', errorbar='sd', estimator='median', color='#56C667FF', lw=2, label='mPNA')
axes[1].set_xlabel('Concentrations [µM]')
axes[1].set_ylabel('Percentage of Mitochondria Contamination')

plt.savefig('line_plots_wConf.png', dpi=200)
plt.show()

# %% [markdown]
# #### Seperate ones for the manuscript

# %%
plt.figure(figsize=(5, 4))
sns.lineplot(data=pPNA, x='pPNA', y='Chloroplast', errorbar='sd', estimator='median', color='#74D055FF', lw=2, label='pPNA', legend=False)
plt.xlabel('pPNA concentrations [µM]')
plt.ylabel('Percentage of Chloroplast Contamination')
plt.ylim(0, 100)  # Set y-axis range
plt.savefig('chloroplast_line_plot_wConf.png', dpi=200)
plt.show()

# %%
plt.figure(figsize=(5, 4))
#sns.lineplot(data=mpPNA, x='mPNA', y='Mitochondria', errorbar='sd', estimator='median', color='#440154FF', lw=2, label='m+pPNA', legend=False)
sns.lineplot(data=mPNA, x='mPNA', y='Mitochondria', errorbar='sd', estimator='median', color='#FDE725FF', lw=2, label='mPNA', legend=False)
plt.xlabel('mPNA concentrations [µM]')
plt.ylabel('Percentage of Mitochondria Contamination')
plt.ylim(0, 20)  # Set y-axis range
plt.yticks(range(0, 21, 5))  # Set y-axis ticks every 5
plt.savefig('mitochondria_line_plot_wConf.png', dpi=200)
plt.show()

# %% [markdown]
# ### Calculate numbers of read loss

# %%
# Calculate median and SE for Chloroplast column
median_chloroplast_mpPNA = mpPNA.groupby('mPNA')['Chloroplast'].median()
se_chloroplast_mpPNA = mpPNA.groupby('mPNA')['Chloroplast'].sem()

median_chloroplast_pPNA = pPNA.groupby('pPNA')['Chloroplast'].median()
se_chloroplast_pPNA = pPNA.groupby('pPNA')['Chloroplast'].sem()

median_chloroplast_mPNA = mPNA.groupby('mPNA')['Chloroplast'].median()
se_chloroplast_mPNA = mPNA.groupby('mPNA')['Chloroplast'].sem()

# Calculate median and SE for Mitochondria column
median_mitochondria_mpPNA = mpPNA.groupby('mPNA')['Mitochondria'].median()
se_mitochondria_mpPNA = mpPNA.groupby('mPNA')['Mitochondria'].sem()

median_mitochondria_pPNA = pPNA.groupby('pPNA')['Mitochondria'].median()
se_mitochondria_pPNA = pPNA.groupby('pPNA')['Mitochondria'].sem()

median_mitochondria_mPNA = mPNA.groupby('mPNA')['Mitochondria'].median()
se_mitochondria_mPNA = mPNA.groupby('mPNA')['Mitochondria'].sem()

# Print median and SE values for Chloroplast
print("Chloroplast mpPNA Median:\n", median_chloroplast_mpPNA)
print("Chloroplast mpPNA SE:\n", se_chloroplast_mpPNA)
print("\nChloroplast pPNA Median:\n", median_chloroplast_pPNA)
print("Chloroplast pPNA SE:\n", se_chloroplast_pPNA)
print("\nChloroplast mPNA Median:\n", median_chloroplast_mPNA)
print("Chloroplast mPNA SE:\n", se_chloroplast_mPNA)

# Print median and SE values for Mitochondria
print("\nMitochondria mpPNA Median:\n", median_mitochondria_mpPNA)
print("Mitochondria mpPNA SE:\n", se_mitochondria_mpPNA)
print("\nMitochondria pPNA Median:\n", median_mitochondria_pPNA)
print("Mitochondria pPNA SE:\n", se_mitochondria_pPNA)
print("\nMitochondria mPNA Median:\n", median_mitochondria_mPNA)
print("Mitochondria mPNA SE:\n", se_mitochondria_mPNA)
# Out:
# Chloroplast mpPNA Median:
#  mPNA
# 0.00    93.696367
# 0.25    50.158386
# 0.50    29.450056
# 0.75    33.957219
# 1.00    28.832503
# 1.25    32.235294
# Name: Chloroplast, dtype: float64
# Chloroplast mpPNA SE:
#  mPNA
# 0.00    13.569466
# 0.25     9.728626
# 0.50    12.937855
# 0.75     8.824781
# 1.00    10.359721
# 1.25     8.448960
# Name: Chloroplast, dtype: float64
#
# Chloroplast pPNA Median:
#  pPNA
# 0.00    93.696367
# 0.25    18.714756
# 0.50    19.226915
# 0.75    28.612835
# 1.00    21.992592
# 1.25    20.968866
# Name: Chloroplast, dtype: float64
# Chloroplast pPNA SE:
#  pPNA
# 0.00    13.569466
# 0.25     9.092649
# 0.50     4.201373
# 0.75     8.398255
# 1.00    10.035959
# 1.25     7.023779
# Name: Chloroplast, dtype: float64
#
# Chloroplast mPNA Median:
#  mPNA
# 0.00    93.696367
# 0.25    94.518700
# 0.50    94.044160
# 0.75    94.814815
# 1.00    94.620779
# 1.25    94.171348
# Name: Chloroplast, dtype: float64
# Chloroplast mPNA SE:
#  mPNA
# 0.00    13.569466
# 0.25    10.035662
# 0.50    10.849111
# 0.75    16.523486
# 1.00    13.966654
# 1.25    13.165738
# Name: Chloroplast, dtype: float64
#
# Mitochondria mpPNA Median:
#  mPNA
# 0.00     4.301473
# 0.25    18.552036
# 0.50    12.074774
# 0.75    25.302612
# 1.00    36.158702
# 1.25    18.602033
# Name: Mitochondria, dtype: float64
# Mitochondria mpPNA SE:
#  mPNA
# 0.00     4.331273
# 0.25     4.651152
# 0.50     5.890749
# 0.75    10.007874
# 1.00     9.083379
# 1.25     5.952851
# Name: Mitochondria, dtype: float64
#
# Mitochondria pPNA Median:
#  pPNA
# 0.00     4.301473
# 0.25    46.795174
# 0.50    55.206731
# 0.75    56.801854
# 1.00    34.375000
# 1.25    45.744681
# Name: Mitochondria, dtype: float64
# Mitochondria pPNA SE:
#  pPNA
# 0.00     4.331273
# 0.25    11.161901
# 0.50     8.319769
# 0.75     9.538278
# 1.00    10.653174
# 1.25     9.258550
# Name: Mitochondria, dtype: float64
#
# Mitochondria mPNA Median:
#  mPNA
# 0.00    4.301473
# 0.25    0.339831
# 0.50    0.305381
# 0.75    0.148303
# 1.00    0.171270
# 1.25    0.351921
# Name: Mitochondria, dtype: float64
# Mitochondria mPNA SE:
#  mPNA
# 0.00    4.331273
# 0.25    3.976669
# 0.50    4.121183
# 0.75    4.268332
# 1.00    2.050227
# 1.25    2.949064
# Name: Mitochondria, dtype: float64

# %%
# Calculate min and max for Chloroplast column
min_chloroplast_mpPNA = mpPNA.groupby('mPNA')['Chloroplast'].min()
max_chloroplast_mpPNA = mpPNA.groupby('mPNA')['Chloroplast'].max()

min_chloroplast_pPNA = pPNA.groupby('pPNA')['Chloroplast'].min()
max_chloroplast_pPNA = pPNA.groupby('pPNA')['Chloroplast'].max()

min_chloroplast_mPNA = mPNA.groupby('mPNA')['Chloroplast'].min()
max_chloroplast_mPNA = mPNA.groupby('mPNA')['Chloroplast'].max()

# Calculate min and max for Mitochondria column
min_mitochondria_mpPNA = mpPNA.groupby('mPNA')['Mitochondria'].min()
max_mitochondria_mpPNA = mpPNA.groupby('mPNA')['Mitochondria'].max()

min_mitochondria_pPNA = pPNA.groupby('pPNA')['Mitochondria'].min()
max_mitochondria_pPNA = pPNA.groupby('pPNA')['Mitochondria'].max()

min_mitochondria_mPNA = mPNA.groupby('mPNA')['Mitochondria'].min()
max_mitochondria_mPNA = mPNA.groupby('mPNA')['Mitochondria'].max()

# Print min and max values for Chloroplast
print("Chloroplast mpPNA Min:\n", min_chloroplast_mpPNA)
print("Chloroplast mpPNA Max:\n", max_chloroplast_mpPNA)
print("\nChloroplast pPNA Min:\n", min_chloroplast_pPNA)
print("Chloroplast pPNA Max:\n", max_chloroplast_pPNA)
print("\nChloroplast mPNA Min:\n", min_chloroplast_mPNA)
print("Chloroplast mPNA Max:\n", max_chloroplast_mPNA)

# Print min and max values for Mitochondria
print("\nMitochondria mpPNA Min:\n", min_mitochondria_mpPNA)
print("Mitochondria mpPNA Max:\n", max_mitochondria_mpPNA)
print("\nMitochondria pPNA Min:\n", min_mitochondria_pPNA)
print("Mitochondria pPNA Max:\n", max_mitochondria_pPNA)
print("\nMitochondria mPNA Min:\n", min_mitochondria_mPNA)
print("Mitochondria mPNA Max:\n", max_mitochondria_mPNA)
# Out:
# Chloroplast mpPNA Min:
#  mPNA
# 0.00    14.951108
# 0.25    12.071918
# 0.50     5.151614
# 0.75    10.551559
# 1.00    14.147961
# 1.25     6.675749
# Name: Chloroplast, dtype: float64
# Chloroplast mpPNA Max:
#  mPNA
# 0.00    96.805252
# 0.25    86.317255
# 0.50    85.970344
# 0.75    71.934953
# 1.00    85.962764
# 1.25    78.401515
# Name: Chloroplast, dtype: float64
#
# Chloroplast pPNA Min:
#  pPNA
# 0.00    14.951108
# 0.25     7.328683
# 0.50    12.076315
# 0.75     9.246446
# 1.00     7.453338
# 1.25     1.063830
# Name: Chloroplast, dtype: float64
# Chloroplast pPNA Max:
#  pPNA
# 0.00    96.805252
# 0.25    79.597438
# 0.50    37.442002
# 0.75    75.210084
# 1.00    72.871998
# 1.25    46.119233
# Name: Chloroplast, dtype: float64
#
# Chloroplast mPNA Min:
#  mPNA
# 0.00    14.951108
# 0.25    42.592593
# 0.50    28.571429
# 0.75     0.145128
# 1.00     0.199853
# 1.25    11.936699
# Name: Chloroplast, dtype: float64
# Chloroplast mPNA Max:
#  mPNA
# 0.00    96.805252
# 0.25    99.777929
# 0.50    99.821225
# 0.75    99.834793
# 1.00    99.828698
# 1.25    99.834438
# Name: Chloroplast, dtype: float64
#
# Mitochondria mpPNA Min:
#  mPNA
# 0.00    2.061112
# 0.25    9.931507
# 0.50    0.000000
# 0.75    0.000000
# 1.00    7.128310
# 1.25    3.133515
# Name: Mitochondria, dtype: float64
# Mitochondria mpPNA Max:
#  mPNA
# 0.00    28.030343
# 0.25    43.109674
# 0.50    45.791246
# 0.75    75.630252
# 1.00    64.573991
# 1.25    49.734654
# Name: Mitochondria, dtype: float64
#
# Mitochondria pPNA Min:
#  pPNA
# 0.00     2.061112
# 0.25     4.839067
# 0.50    24.835102
# 0.75     2.521008
# 1.00     6.445270
# 1.25    13.033942
# Name: Mitochondria, dtype: float64
# Mitochondria pPNA Max:
#  pPNA
# 0.00    28.030343
# 0.25    78.442072
# 0.50    83.636989
# 0.75    73.770289
# 1.00    87.650299
# 1.25    84.137357
# Name: Mitochondria, dtype: float64
#
# Mitochondria mPNA Min:
#  mPNA
# 0.00    2.061112
# 0.25    0.000000
# 0.50    0.000000
# 0.75    0.000000
# 1.00    0.028921
# 1.25    0.000000
# Name: Mitochondria, dtype: float64
# Mitochondria mPNA Max:
#  mPNA
# 0.00    28.030343
# 0.25    23.915999
# 0.50    28.571429
# 0.75    25.124387
# 1.00    12.031454
# 1.25    19.009126
# Name: Mitochondria, dtype: float64

# %%
# Lineplots! 
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.lineplot(ax=axes[0], data=medians_chloroplast, palette='viridis')
axes[0].set_xlabel('Concentrations [µM]')
axes[0].set_ylabel('Percentage of Chloroplast Contamination')

sns.lineplot(ax=axes[1], data=medians_mitochondria, palette='viridis')
axes[1].set_xlabel('Concentrations [µM]')
axes[1].set_ylabel('Percentage of Mitochondria Contamination')

plt.savefig('line_plots.png', dpi=200)
plt.show()

# %% [markdown]
# ## Collapsed Q2 Taxa Barplot

# %%
# Group samples by PNA_composition 
md_col = md.get_column('PNA_composition')

grouped_table, = group(table=table_PNAs,
                      axis='sample',
                      metadata=md_col,
                      mode='median-ceiling')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 # Group samples by PNA_composition
#       2 md_col = md.get_column('PNA_composition')
# ----> 4 grouped_table, = group(table=table_PNAs,
#       5                       axis='sample',
#       6                       metadata=md_col,
#       7                       mode='median-ceiling')
#
# NameError: name 'table_PNAs' is not defined

# %%
taxa_bar_plots_viz, = taxa_actions.barplot(
    table=grouped_table,
    taxonomy=taxonomy
)
taxa_bar_plots_viz.save('taxa_barplot_grouped.qzv')
# Out:
# 'taxa_barplot_grouped.qzv'

# %%
Visualization.load('taxa_barplot_grouped.qzv')
# Out:
# <visualization: Visualization uuid: 264cda90-62dc-4844-b8e9-84dd99823bdd>

# %% [markdown]
# # 2020 Taxa Barplot
#
# These are the same grape must samples (385 total) sequenced in 2020 without PNA blockers.

# %%
must_2020 = pd.read_csv('2020-taxabarplot.csv')


taxa_of_interest = ['d__Bacteria;p__Cyanobacteria;c__Cyanobacteriia;o__Chloroplast;f__Chloroplast',
                    'd__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rickettsiales;f__Mitochondria']
    
rename_dict = {'d__Bacteria;p__Cyanobacteria;c__Cyanobacteriia;o__Chloroplast;f__Chloroplast':'Chloroplast',
              'd__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rickettsiales;f__Mitochondria':'Mitochondria'}


# rename the taxa of interest
must_2020 = must_2020.rename(columns=rename_dict)
# Sum up all columns that are not in the taxa_of_interest and add as 'Other'
must_2020['Other'] = must_2020.drop(columns=rename_dict.values()).sum(axis=1)
# Drop the original non-interest columns (already summed in 'Other')
must_2020 = must_2020[rename_dict.values()].join(must_2020['Other'])
# Calculate relative frequencies
must_2020 = must_2020.div(must_2020.sum(axis=1), axis=0) * 100

must_2020.head()
# Out:
# /scratch/lfloerl/tmpdata/ipykernel_261076/3692417202.py:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   must_2020['Other'] = must_2020.drop(columns=rename_dict.values()).sum(axis=1)
#    Chloroplast  Mitochondria     Other
# 0    92.370462      3.667068  3.962470
# 1    96.341033      2.933842  0.725125
# 2    94.157483      3.282374  2.560143
# 3    90.890059      8.559265  0.550676
# 4    90.834318      8.192779  0.972903

# %%
# Calculating the median and average for each column
must_2020.median()
# Out:
# Chloroplast     90.724482
# Mitochondria     7.758026
# Other            0.988919
# dtype: float64

# %%
must_2020.mean()
# Out:
# Chloroplast     86.685412
# Mitochondria     8.926667
# Other            4.387922
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Sorting the DataFrame by Chloroplast and Mitochondria
must_2020_sorted = must_2020.sort_values(by=['Chloroplast', 'Mitochondria'], ascending=[False, False])

# Plotting the stacked horizontal barplot with a white background
fig, ax = plt.subplots(figsize=(5, 8))

# Plotting the stacked horizontal barplot
must_2020_sorted.plot(kind='barh', stacked=True, ax=ax, color=['#74D055FF', '#FDE725FF', '#39558CFF'])

# Customizing the plot
ax.set_facecolor('white')  # Set background to white
ax.grid(False)  # Remove grid lines
ax.set_xlim(0, 100)  # Set x-axis scale to end at 100

# Set the labels and title
ax.set_xlabel('Relative Frequency (%)')
ax.set_ylabel(' ')
ax.set_yticks([])  # Remove y-axis ticks
ax.set_yticklabels([])  # Remove y-axis labels

# Show the legend outside the plot
plt.legend(loc='lower left', bbox_to_anchor=(0.01, 0.01))

# Adjust layout for better fit
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# <hr>
#
# # 2. Do PNA blockers affect diversity?
#
# ## Filter
# first remove chloroplasts & mitochondria, because that's what we'd also do in a regular diversity analysis and would just skew the analysis

# %%
table_PNAs = q2.Artifact.load('PNA-table.qza')

# load metadata with reads lost to contamination 
md = Metadata.load('/home/lfloerl/RxCS/Metadata/16S_PNA-test-withLoss.tsv')
md_all = Metadata.load('/home/lfloerl/RxCS/Metadata/16S_metadata.tsv')

# %%
exclude_terms = 'mitochondria,chloroplast'

md_filtered_table, = filter_samples(table=table_PNAs,
                                metadata=md,
                                where="[Sample]!='DNA18-pos-1'")

taxa_filtered_table, = q2t.actions.filter_table(
                                table=md_filtered_table, 
                                taxonomy=taxonomy,
                                exclude=exclude_terms)
taxa_filtered_table.save('taxa_filtered_table.qza')
# Out:
# 'taxa_filtered_table.qza'

# %%
# !qiime feature-table summarize --i-table taxa_filtered_table.qza --m-sample-metadata-file /home/lfloerl/RxCS/Metadata/16S_PNA-test-withLoss.tsv --o-visualization taxa_filtered_table.qzv
# Out:
# Saved Visualization to: taxa_filtered_table.qzv

# %%
Visualization.load('taxa_filtered_table.qzv')
# Out:
# <visualization: Visualization uuid: 184903a5-3d1e-4233-840a-50196f185e4a>

# %% [markdown]
# ## Rarefaction

# %%
alpha_rarefaction, = q2d.visualizers.alpha_rarefaction(table=taxa_filtered_table, 
                                                       max_depth=1000,
                                                       metadata=md)
alpha_rarefaction.save('alpha_rarefaction_curves.qzv')
# Out:
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# 'alpha_rarefaction_curves.qzv'

# %%
Visualization.load('alpha_rarefaction_curves.qzv')
# Out:
# <visualization: Visualization uuid: 1e6826c4-b23c-4821-b6bc-b8d080a1dc7f>

# %% [markdown]
# ## Calculate Diversity Metrics

# %%
# let's try to use more metadata, before merging however we have to rename one
md_all_df = md_all.to_dataframe()
md_all_df.rename(columns=lambda x: f'{x}_all', inplace=True)
md_all_renamed = Metadata(md_all_df)

merged_metadata = md.merge(md_all_renamed)

# %%
merged_metadata.to_dataframe()
# Out:
#                          phylum_filtered_table  contaminants_filtered_table  \
# id
# 346832_001-LP1-16S-0097               668672.0                     563316.0
# 346832_002-LP1-16S-0098               764294.0                     688882.0
# 346832_003-LP1-16S-0099               878608.0                     835291.0
# 346832_004-LP1-16S-0100               378428.0                      25262.0
# 346832_005-LP1-16S-0101               719925.0                     590457.0
# ...                                        ...                          ...
# 346832_939-LP1-16S-1148               535981.0                        930.0
# 346832_940-LP1-16S-1149               205112.0                      13339.0
# 346832_941-LP1-16S-1150                  592.0                        374.0
# 346832_942-LP1-16S-1151                 4279.0                        393.0
# 346832_943-LP1-16S-1152                  564.0                        339.0
#
#                          ChloroMito_filtered_table  \
# id
# 346832_001-LP1-16S-0097                   563128.0
# 346832_002-LP1-16S-0098                     2851.0
# 346832_003-LP1-16S-0099                      595.0
# 346832_004-LP1-16S-0100                      625.0
# 346832_005-LP1-16S-0101                     1189.0
# ...                                            ...
# 346832_939-LP1-16S-1148                      733.0
# 346832_940-LP1-16S-1149                     1326.0
# 346832_941-LP1-16S-1150                      180.0
# 346832_942-LP1-16S-1151                       89.0
# 346832_943-LP1-16S-1152                      138.0
#
#                          contaminants_filtered_table_percentage  \
# id
# 346832_001-LP1-16S-0097                               84.243994
# 346832_002-LP1-16S-0098                               90.133116
# 346832_003-LP1-16S-0099                               95.069815
# 346832_004-LP1-16S-0100                                6.675510
# 346832_005-LP1-16S-0101                               82.016460
# ...                                                         ...
# 346832_939-LP1-16S-1148                                0.173514
# 346832_940-LP1-16S-1149                                6.503276
# 346832_941-LP1-16S-1150                               63.175676
# 346832_942-LP1-16S-1151                                9.184389
# 346832_943-LP1-16S-1152                               60.106383
#
#                          ChloroMito_filtered_table_percentage PNAs  mPNA  \
# id
# 346832_001-LP1-16S-0097                             84.215879   no  0.00
# 346832_002-LP1-16S-0098                              0.373024   no  0.00
# 346832_003-LP1-16S-0099                              0.067721   no  0.00
# 346832_004-LP1-16S-0100                              0.165157   no  0.00
# 346832_005-LP1-16S-0101                              0.165156   no  0.00
# ...                                                       ...  ...   ...
# 346832_939-LP1-16S-1148                              0.136759  yes  1.25
# 346832_940-LP1-16S-1149                              0.646476  yes  1.25
# 346832_941-LP1-16S-1150                             30.405405  yes  1.25
# 346832_942-LP1-16S-1151                              2.079925  yes  1.25
# 346832_943-LP1-16S-1152                             24.468085  yes  1.25
#
#                          pPNA    PNA_mix    PNA_composition  ... GT_all  \
# id                                                           ...
# 346832_001-LP1-16S-0097  0.00       None         None0.00.0  ...    NaN
# 346832_002-LP1-16S-0098  0.00       None         None0.00.0  ...   gt48
# 346832_003-LP1-16S-0099  0.00       None         None0.00.0  ...   gt48
# 346832_004-LP1-16S-0100  0.00       None         None0.00.0  ...  gt110
# 346832_005-LP1-16S-0101  0.00       None         None0.00.0  ...  gt147
# ...                       ...        ...                ...  ...    ...
# 346832_939-LP1-16S-1148  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...  gt110
# 346832_940-LP1-16S-1149  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...  gt147
# 346832_941-LP1-16S-1150  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...   gt64
# 346832_942-LP1-16S-1151  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...    gt5
# 346832_943-LP1-16S-1152  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...  gt120
#
#                                   Block_all   Block_no_all Year_Cat_all  \
# id
# 346832_001-LP1-16S-0097                 NaN            NaN      Yearnan
# 346832_002-LP1-16S-0098     Block2_noPNAs_0     2_noPNAs_0     Year2022
# 346832_003-LP1-16S-0099     Block1_noPNAs_0     1_noPNAs_0     Year2022
# 346832_004-LP1-16S-0100     Block1_noPNAs_0     1_noPNAs_0     Year2022
# 346832_005-LP1-16S-0101     Block2_noPNAs_0     2_noPNAs_0     Year2022
# ...                                     ...            ...          ...
# 346832_939-LP1-16S-1148  Block1_m+pPNA_1.25  1_m+pPNA_1.25     Year2022
# 346832_940-LP1-16S-1149  Block2_m+pPNA_1.25  2_m+pPNA_1.25     Year2022
# 346832_941-LP1-16S-1150  Block2_m+pPNA_1.25  2_m+pPNA_1.25     Year2022
# 346832_942-LP1-16S-1151  Block2_m+pPNA_1.25  2_m+pPNA_1.25     Year2022
# 346832_943-LP1-16S-1152  Block1_m+pPNA_1.25  1_m+pPNA_1.25     Year2022
#
#                         GT_numb_all  Average_Brix_all  \
# id
# 346832_001-LP1-16S-0097         NaN               NaN
# 346832_002-LP1-16S-0098          48              23.0
# 346832_003-LP1-16S-0099          48               NaN
# 346832_004-LP1-16S-0100         110              20.8
# 346832_005-LP1-16S-0101         147               NaN
# ...                             ...               ...
# 346832_939-LP1-16S-1148         110               NaN
# 346832_940-LP1-16S-1149         147               NaN
# 346832_941-LP1-16S-1150          64               NaN
# 346832_942-LP1-16S-1151           5               NaN
# 346832_943-LP1-16S-1152         120               NaN
#
#                         Average_Cluster_Weight_all Genotype_all  \
# id
# 346832_001-LP1-16S-0097                        NaN          NaN
# 346832_002-LP1-16S-0098                  85.666667           48
# 346832_003-LP1-16S-0099                        NaN           48
# 346832_004-LP1-16S-0100                  36.666667          110
# 346832_005-LP1-16S-0101                        NaN          147
# ...                                            ...          ...
# 346832_939-LP1-16S-1148                        NaN          110
# 346832_940-LP1-16S-1149                        NaN          147
# 346832_941-LP1-16S-1150                        NaN           64
# 346832_942-LP1-16S-1151                        NaN            5
# 346832_943-LP1-16S-1152                        NaN          120
#
#                          Berry_Color_all  control_all
# id
# 346832_001-LP1-16S-0097              NaN     pos_ctrl
# 346832_002-LP1-16S-0098              Red       sample
# 346832_003-LP1-16S-0099              Red       sample
# 346832_004-LP1-16S-0100              Red       sample
# 346832_005-LP1-16S-0101              Red       sample
# ...                                  ...          ...
# 346832_939-LP1-16S-1148              Red       sample
# 346832_940-LP1-16S-1149              Red       sample
# 346832_941-LP1-16S-1150            White       sample
# 346832_942-LP1-16S-1151              Red       sample
# 346832_943-LP1-16S-1152              Red       sample
#
# [128 rows x 32 columns]

# %%
depth = 100

threads = 5

# %%
core_div_dict = {}

core_div = q2d.actions.core_metrics(table=taxa_filtered_table,
                                                 sampling_depth=depth,
                                                 metadata=merged_metadata,
                                                 n_jobs=threads)
# save outputs
output_dir='cm{0}/'.format(depth)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
for k, v in core_div.__dict__.items():
    if k != '_fields':
        v.save(output_dir + k)
        core_div_dict[k] = v
# Out:
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.08031969839102272 and the largest is 6.929744801417249.
#   warn(
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:143: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.12325628009391362 and the largest is 7.649439431640764.
#   warn(

# %%
#output_dir = 'cm100'

# %%
Visualization.load(f'{wd}/{output_dir}/bray_curtis_emperor.qzv')
# Out:
# <visualization: Visualization uuid: ada27970-9121-4abb-9f8a-2573936d1e22>

# %%
Visualization.load(f'{wd}/{output_dir}/jaccard_emperor.qzv')
# Out:
# <visualization: Visualization uuid: c7f86ee0-aa0a-41d6-bbb0-217be153970e>

# %% [markdown]
# ## Differential Abundance with ANCOM

# %%
merged_metadata.to_dataframe()
# Out:
#                          phylum_filtered_table  contaminants_filtered_table  \
# id
# 346832_001-LP1-16S-0097               668672.0                     563316.0
# 346832_002-LP1-16S-0098               764294.0                     688882.0
# 346832_003-LP1-16S-0099               878608.0                     835291.0
# 346832_004-LP1-16S-0100               378428.0                      25262.0
# 346832_005-LP1-16S-0101               719925.0                     590457.0
# ...                                        ...                          ...
# 346832_939-LP1-16S-1148               535981.0                        930.0
# 346832_940-LP1-16S-1149               205112.0                      13339.0
# 346832_941-LP1-16S-1150                  592.0                        374.0
# 346832_942-LP1-16S-1151                 4279.0                        393.0
# 346832_943-LP1-16S-1152                  564.0                        339.0
#
#                          ChloroMito_filtered_table  \
# id
# 346832_001-LP1-16S-0097                   563128.0
# 346832_002-LP1-16S-0098                     2851.0
# 346832_003-LP1-16S-0099                      595.0
# 346832_004-LP1-16S-0100                      625.0
# 346832_005-LP1-16S-0101                     1189.0
# ...                                            ...
# 346832_939-LP1-16S-1148                      733.0
# 346832_940-LP1-16S-1149                     1326.0
# 346832_941-LP1-16S-1150                      180.0
# 346832_942-LP1-16S-1151                       89.0
# 346832_943-LP1-16S-1152                      138.0
#
#                          contaminants_filtered_table_percentage  \
# id
# 346832_001-LP1-16S-0097                               84.243994
# 346832_002-LP1-16S-0098                               90.133116
# 346832_003-LP1-16S-0099                               95.069815
# 346832_004-LP1-16S-0100                                6.675510
# 346832_005-LP1-16S-0101                               82.016460
# ...                                                         ...
# 346832_939-LP1-16S-1148                                0.173514
# 346832_940-LP1-16S-1149                                6.503276
# 346832_941-LP1-16S-1150                               63.175676
# 346832_942-LP1-16S-1151                                9.184389
# 346832_943-LP1-16S-1152                               60.106383
#
#                          ChloroMito_filtered_table_percentage PNAs  mPNA  \
# id
# 346832_001-LP1-16S-0097                             84.215879   no  0.00
# 346832_002-LP1-16S-0098                              0.373024   no  0.00
# 346832_003-LP1-16S-0099                              0.067721   no  0.00
# 346832_004-LP1-16S-0100                              0.165157   no  0.00
# 346832_005-LP1-16S-0101                              0.165156   no  0.00
# ...                                                       ...  ...   ...
# 346832_939-LP1-16S-1148                              0.136759  yes  1.25
# 346832_940-LP1-16S-1149                              0.646476  yes  1.25
# 346832_941-LP1-16S-1150                             30.405405  yes  1.25
# 346832_942-LP1-16S-1151                              2.079925  yes  1.25
# 346832_943-LP1-16S-1152                             24.468085  yes  1.25
#
#                          pPNA    PNA_mix    PNA_composition  ... GT_all  \
# id                                                           ...
# 346832_001-LP1-16S-0097  0.00       None         None0.00.0  ...    NaN
# 346832_002-LP1-16S-0098  0.00       None         None0.00.0  ...   gt48
# 346832_003-LP1-16S-0099  0.00       None         None0.00.0  ...   gt48
# 346832_004-LP1-16S-0100  0.00       None         None0.00.0  ...  gt110
# 346832_005-LP1-16S-0101  0.00       None         None0.00.0  ...  gt147
# ...                       ...        ...                ...  ...    ...
# 346832_939-LP1-16S-1148  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...  gt110
# 346832_940-LP1-16S-1149  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...  gt147
# 346832_941-LP1-16S-1150  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...   gt64
# 346832_942-LP1-16S-1151  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...    gt5
# 346832_943-LP1-16S-1152  1.25  mPNA+pPNA  mPNA+pPNA1.251.25  ...  gt120
#
#                                   Block_all   Block_no_all Year_Cat_all  \
# id
# 346832_001-LP1-16S-0097                 NaN            NaN      Yearnan
# 346832_002-LP1-16S-0098     Block2_noPNAs_0     2_noPNAs_0     Year2022
# 346832_003-LP1-16S-0099     Block1_noPNAs_0     1_noPNAs_0     Year2022
# 346832_004-LP1-16S-0100     Block1_noPNAs_0     1_noPNAs_0     Year2022
# 346832_005-LP1-16S-0101     Block2_noPNAs_0     2_noPNAs_0     Year2022
# ...                                     ...            ...          ...
# 346832_939-LP1-16S-1148  Block1_m+pPNA_1.25  1_m+pPNA_1.25     Year2022
# 346832_940-LP1-16S-1149  Block2_m+pPNA_1.25  2_m+pPNA_1.25     Year2022
# 346832_941-LP1-16S-1150  Block2_m+pPNA_1.25  2_m+pPNA_1.25     Year2022
# 346832_942-LP1-16S-1151  Block2_m+pPNA_1.25  2_m+pPNA_1.25     Year2022
# 346832_943-LP1-16S-1152  Block1_m+pPNA_1.25  1_m+pPNA_1.25     Year2022
#
#                         GT_numb_all  Average_Brix_all  \
# id
# 346832_001-LP1-16S-0097         NaN               NaN
# 346832_002-LP1-16S-0098          48              23.0
# 346832_003-LP1-16S-0099          48               NaN
# 346832_004-LP1-16S-0100         110              20.8
# 346832_005-LP1-16S-0101         147               NaN
# ...                             ...               ...
# 346832_939-LP1-16S-1148         110               NaN
# 346832_940-LP1-16S-1149         147               NaN
# 346832_941-LP1-16S-1150          64               NaN
# 346832_942-LP1-16S-1151           5               NaN
# 346832_943-LP1-16S-1152         120               NaN
#
#                         Average_Cluster_Weight_all Genotype_all  \
# id
# 346832_001-LP1-16S-0097                        NaN          NaN
# 346832_002-LP1-16S-0098                  85.666667           48
# 346832_003-LP1-16S-0099                        NaN           48
# 346832_004-LP1-16S-0100                  36.666667          110
# 346832_005-LP1-16S-0101                        NaN          147
# ...                                            ...          ...
# 346832_939-LP1-16S-1148                        NaN          110
# 346832_940-LP1-16S-1149                        NaN          147
# 346832_941-LP1-16S-1150                        NaN           64
# 346832_942-LP1-16S-1151                        NaN            5
# 346832_943-LP1-16S-1152                        NaN          120
#
#                          Berry_Color_all  control_all
# id
# 346832_001-LP1-16S-0097              NaN     pos_ctrl
# 346832_002-LP1-16S-0098              Red       sample
# 346832_003-LP1-16S-0099              Red       sample
# 346832_004-LP1-16S-0100              Red       sample
# 346832_005-LP1-16S-0101              Red       sample
# ...                                  ...          ...
# 346832_939-LP1-16S-1148              Red       sample
# 346832_940-LP1-16S-1149              Red       sample
# 346832_941-LP1-16S-1150            White       sample
# 346832_942-LP1-16S-1151              Red       sample
# 346832_943-LP1-16S-1152              Red       sample
#
# [128 rows x 32 columns]

# %%
filtered_table, = qft.actions.filter_features(taxa_filtered_table, min_frequency = 5, min_samples = 1)
ancom_table, = comp.methods.add_pseudocount(filtered_table)
ancom_table.save('ancom_table.qza')

# %%
ancom = comp.actions.ancom(table=ancom_table, metadata=merged_metadata.get_column('PNAs'))
ancom.visualization
# PNAs.tsv
# Out:
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# <visualization: Visualization uuid: 027b8ee7-6985-4811-a5e9-bba051fbc448>

# %%
ancom = comp.actions.ancom(table=ancom_table, metadata=merged_metadata.get_column('PNA_composition'))
ancom.visualization
# PNA_composition.tsv
# Out:
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# <visualization: Visualization uuid: 1b80e4c8-d408-4b19-8f9d-9715ebb79ee3>

# %%
ancom = comp.actions.ancom(table=ancom_table, metadata=merged_metadata.get_column('PNA_mix'))
ancom.visualization
# PNA_mix.tsv
# Out:
# /scratch/lfloerl/.condaenvs/qiime2-amplicon-2024.2/lib/python3.8/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# <visualization: Visualization uuid: bdb1afe3-c20d-49db-a979-3919583aee05>

# %% [markdown]
# save as tsv and merge with taxonomy:

# %%
# %%bash
#
#  # combine the taxa table with the abundant features
# qiime metadata tabulate \
#   --m-input-file /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/taxonomy.qza  \
#   --m-input-file ANCOM/PNAs.tsv \
#   --o-visualization ANCOM/ANCOM_PNAs.qzv
#
# qiime metadata tabulate \
#   --m-input-file /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/taxonomy.qza  \
#   --m-input-file ANCOM/PNA_mix.tsv \
#   --o-visualization ANCOM/ANCOM_PNAmix.qzv
#
# qiime metadata tabulate \
#   --m-input-file /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/taxonomy.qza  \
#   --m-input-file ANCOM/PNA_composition.tsv \
#   --o-visualization ANCOM/ANCOM_PNAcomposition.qzv
# Out:
# Saved Visualization to: ANCOM/ANCOM_PNAs.qzv
# Saved Visualization to: ANCOM/ANCOM_PNAmix.qzv
# Saved Visualization to: ANCOM/ANCOM_PNAcomposition.qzv

# %%
Visualization.load('ANCOM/ANCOM_PNAs.qzv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Visualization.load('ANCOM/ANCOM_PNAs.qzv')
#
# NameError: name 'Visualization' is not defined

# %%
Visualization.load('ANCOM/ANCOM_PNAmix.qzv')
# Out:
# <visualization: Visualization uuid: 2d423884-5fd2-48e1-8b94-c725f76be6e1>

# %%
Visualization.load('ANCOM/ANCOM_PNAcomposition.qzv')
# Out:
# <visualization: Visualization uuid: 3bb86868-23ce-43bd-ac24-093ea13c0c89>

# %% [markdown]
# ## Nicer visualizations of the PCoA

# %%
#!qiime tools export --input-path cm100/jaccard_pcoa_results.qza --output-path cm100/jaccard_pcoa
#!qiime tools export --input-path cm100/bray_curtis_pcoa_results.qza --output-path cm100/bray_curtis_pcoa
# Out:
# Exported cm100/jaccard_pcoa_results.qza as OrdinationDirectoryFormat to directory cm100/jaccard_pcoa
# Exported cm100/bray_curtis_pcoa_results.qza as OrdinationDirectoryFormat to directory cm100/bray_curtis_pcoa

# %%
# reimport 
bc_pcoa = pd.read_csv('cm100/bray_curtis_pcoa/ordination.txt', sep='\t', skiprows=9, header=None)
jaccard_pcoa = pd.read_csv('cm100/jaccard_pcoa/ordination.txt', sep='\t', skiprows=9, header=None)

# function to get components 
def select_components(df):
    # Drop the last 4 rows
    df = df.iloc[:-4]
    # Select specific columns
    df = df.iloc[:, [0, 1, 3]]
    # Rename columns and set index
    df = df.rename(columns={0: 'ID', 1: 'PC1', 3: 'PC2'}).set_index('ID')
    return df

bc_pcoa_df = select_components(bc_pcoa)
jaccard_pcoa_df = select_components(jaccard_pcoa)

# %%
# rename the index by the sample type 
md = pd.read_csv('/home/lfloerl/RxCS/Metadata/16S_PNA-test-withLoss.tsv', sep='\t')

bc_pcoa_df_merged = bc_pcoa_df.merge(md[['sample-id', 'PNAs', 'Sample']], left_on='ID', right_on='sample-id', how='left')
jaccard_pcoa_df_merged = jaccard_pcoa_df.merge(md[['sample-id', 'PNAs', 'Sample']], left_on='ID', right_on='sample-id', how='left')

# %%
sample_mapping = {original: f"Sample-{i+1}" for i, original in enumerate(bc_pcoa_df_merged['Sample'].unique())}
bc_pcoa_df_merged['Sample'] = bc_pcoa_df_merged['Sample'].replace(sample_mapping)
jaccard_pcoa_df_merged['Sample'] = jaccard_pcoa_df_merged['Sample'].replace(sample_mapping)


bc_pcoa_df_merged.head()
# Out:
#         PC1       PC2                sample-id PNAs    Sample
# 0  0.096979  0.054030  346832_002-LP1-16S-0098   no  Sample-1
# 1 -0.571601 -0.154587  346832_003-LP1-16S-0099   no  Sample-2
# 2  0.337597 -0.294252  346832_004-LP1-16S-0100   no  Sample-3
# 3  0.077345  0.430915  346832_005-LP1-16S-0101   no  Sample-4
# 4  0.005389 -0.007532  346832_006-LP1-16S-0102   no  Sample-5

# %%
manual_colors = {
    "Sample-1": "#440154FF",
    "Sample-2": "#443A83FF",
    "Sample-3": "#31688EFF",
    "Sample-4": "#21908CFF",
    "Sample-5": "#35B779FF",
    "Sample-6": "#8FD744FF",
    "Sample-7": "#FDE725FF"
}

# %%
# Map the colors to the DataFrame
bc_pcoa_df_merged['color'] = bc_pcoa_df_merged['Sample'].map(manual_colors)

# Define marker styles based on PNAs
marker_styles = {'yes': 'o', 'no': '*'}

# Create figure
plt.figure(figsize=(3, 3))
plt.tight_layout()

# Plot the remaining markers
other_data = bc_pcoa_df_merged[bc_pcoa_df_merged['PNAs'] != 'no']
sns.scatterplot(
    x='PC1', y='PC2',
    data=other_data,
    hue='Sample',
    palette=manual_colors,
    style='PNAs',
    markers=marker_styles['yes'],
    s=60,
    edgecolor='none',
    legend=None
)

# Plot markers with star style separately
star_data = bc_pcoa_df_merged[bc_pcoa_df_merged['PNAs'] == 'no']
sns.scatterplot(
    x='PC1', y='PC2',
    data=star_data,
    hue='Sample',
    palette=manual_colors,
    style='PNAs',
    markers=marker_styles['no'],
    s=200,  # Larger size for star markers
    edgecolor='black',  # Edge color for star markers
    legend=None
)


# Create custom legend
handles = [
    plt.Line2D([], [], marker=marker_styles['yes'], color='w', markerfacecolor='grey', markersize=10, label='with PNAs'),
    plt.Line2D([], [], marker=marker_styles['no'], color='w', markerfacecolor='grey', markersize=15, markeredgecolor='black', label='without PNAs'),
    plt.Line2D([], [], color='none', label='   '),  # Spacer
]
handles += [plt.Line2D([], [], marker='o', color='w', markerfacecolor=color, markersize=10, label=index)
            for index, color in manual_colors.items()]

plt.legend(
    handles=handles,
    bbox_to_anchor=(1.05, 1),
    loc='upper left',
    handlelength=2,  # Length of the legend handle
    handletextpad=1.1,  # Space between the handle and the label
    columnspacing=2  # Space between columns (if multiple columns are used)
)

# Add labels and title
plt.xlabel('PC1')
plt.ylabel('PC2')

plt.savefig('BC_PCoA.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Map the colors to the DataFrame
jaccard_pcoa_df_merged['color'] = jaccard_pcoa_df_merged['Sample'].map(manual_colors)

# Define marker styles based on PNAs
marker_styles = {'yes': 'o', 'no': '*'}

# Create figure
plt.figure(figsize=(3, 3))
plt.tight_layout()

# Plot the remaining markers
other_data = jaccard_pcoa_df_merged[jaccard_pcoa_df_merged['PNAs'] != 'no']
sns.scatterplot(
    x='PC1', y='PC2',
    data=other_data,
    hue='Sample',
    palette=manual_colors,
    style='PNAs',
    markers=marker_styles['yes'],
    s=60,
    edgecolor='none',
    legend=None
)

# Plot markers with star style separately

star_data = jaccard_pcoa_df_merged[jaccard_pcoa_df_merged['PNAs'] == 'no']
sns.scatterplot(
    x='PC1', y='PC2',
    data=star_data,
    hue='Sample',
    palette=manual_colors,
    style='PNAs',
    markers=marker_styles['no'],
    s=200,  # Larger size for star markers
    edgecolor='black',  # Edge color for star markers
    legend=None
)

# Create custom legend
handles = [
    plt.Line2D([], [], marker=marker_styles['yes'], color='w', markerfacecolor='grey', markersize=10, label='with PNAs'),
    plt.Line2D([], [], marker=marker_styles['no'], color='w', markerfacecolor='grey', markersize=15, markeredgecolor='black', label='without PNAs'),
    plt.Line2D([], [], color='none', label='   '),  # Spacer
]
handles += [plt.Line2D([], [], marker='o', color='w', markerfacecolor=color, markersize=10, label=index)
            for index, color in manual_colors.items()]

plt.legend(
    handles=handles,
    bbox_to_anchor=(1.05, 1),
    loc='upper left',
    handlelength=2,  # Length of the legend handle
    handletextpad=1.1,  # Space between the handle and the label
    columnspacing=2  # Space between columns (if multiple columns are used)
)

# Add labels and title
plt.xlabel('PC1')
plt.ylabel('PC2')

plt.savefig('Jaccard_PCoA.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Alpha Group Significance

# %%
# metrics: 
alpha_metrics = ['shannon_vector', 'observed_features_vector', 'evenness_vector']

for m in alpha_metrics:
    ags, = alpha_group_significance(alpha_diversity = core_div_dict[m],
                               metadata = md)
    ags.save(output_dir + 'alpha_groupSig_{0}.qzv'.format(m))

# %%
output_dir = 'cm100'

# %%
Visualization.load(f'{wd}/{output_dir}/alpha_groupSig_evenness_vector.qzv')
# Out:
# <visualization: Visualization uuid: 2287364c-db46-4a1f-9541-48581176b7a4>

# %%
Visualization.load(f'{wd}/{output_dir}/alpha_groupSig_shannon_vector.qzv')
# Out:
# <visualization: Visualization uuid: a2e1c17a-97c9-4a3f-8c3f-ce65302e878c>

# %%
Visualization.load(f'{wd}/{output_dir}/alpha_groupSig_observed_features_vector.qzv')
# Out:
# <visualization: Visualization uuid: 49c099f9-847b-425a-9367-d8af7c37d0b7>

# %% [markdown]
# ## PERMANOVA with ADONIS

# %%
md.to_dataframe()
# Out:
#                          phylum_filtered_table  contaminants_filtered_table  \
# sample-id
# 346832_001-LP1-16S-0097               668672.0                     563316.0
# 346832_002-LP1-16S-0098               764294.0                     688882.0
# 346832_003-LP1-16S-0099               878608.0                     835291.0
# 346832_004-LP1-16S-0100               378428.0                      25262.0
# 346832_005-LP1-16S-0101               719925.0                     590457.0
# ...                                        ...                          ...
# 346832_939-LP1-16S-1148               535981.0                        930.0
# 346832_940-LP1-16S-1149               205112.0                      13339.0
# 346832_941-LP1-16S-1150                  592.0                        374.0
# 346832_942-LP1-16S-1151                 4279.0                        393.0
# 346832_943-LP1-16S-1152                  564.0                        339.0
#
#                          ChloroMito_filtered_table  \
# sample-id
# 346832_001-LP1-16S-0097                   563128.0
# 346832_002-LP1-16S-0098                     2851.0
# 346832_003-LP1-16S-0099                      595.0
# 346832_004-LP1-16S-0100                      625.0
# 346832_005-LP1-16S-0101                     1189.0
# ...                                            ...
# 346832_939-LP1-16S-1148                      733.0
# 346832_940-LP1-16S-1149                     1326.0
# 346832_941-LP1-16S-1150                      180.0
# 346832_942-LP1-16S-1151                       89.0
# 346832_943-LP1-16S-1152                      138.0
#
#                          contaminants_filtered_table_percentage  \
# sample-id
# 346832_001-LP1-16S-0097                               84.243994
# 346832_002-LP1-16S-0098                               90.133116
# 346832_003-LP1-16S-0099                               95.069815
# 346832_004-LP1-16S-0100                                6.675510
# 346832_005-LP1-16S-0101                               82.016460
# ...                                                         ...
# 346832_939-LP1-16S-1148                                0.173514
# 346832_940-LP1-16S-1149                                6.503276
# 346832_941-LP1-16S-1150                               63.175676
# 346832_942-LP1-16S-1151                                9.184389
# 346832_943-LP1-16S-1152                               60.106383
#
#                          ChloroMito_filtered_table_percentage PNAs  mPNA  \
# sample-id
# 346832_001-LP1-16S-0097                             84.215879   no  0.00
# 346832_002-LP1-16S-0098                              0.373024   no  0.00
# 346832_003-LP1-16S-0099                              0.067721   no  0.00
# 346832_004-LP1-16S-0100                              0.165157   no  0.00
# 346832_005-LP1-16S-0101                              0.165156   no  0.00
# ...                                                       ...  ...   ...
# 346832_939-LP1-16S-1148                              0.136759  yes  1.25
# 346832_940-LP1-16S-1149                              0.646476  yes  1.25
# 346832_941-LP1-16S-1150                             30.405405  yes  1.25
# 346832_942-LP1-16S-1151                              2.079925  yes  1.25
# 346832_943-LP1-16S-1152                             24.468085  yes  1.25
#
#                          pPNA    PNA_mix    PNA_composition  \
# sample-id
# 346832_001-LP1-16S-0097  0.00       None         None0.00.0
# 346832_002-LP1-16S-0098  0.00       None         None0.00.0
# 346832_003-LP1-16S-0099  0.00       None         None0.00.0
# 346832_004-LP1-16S-0100  0.00       None         None0.00.0
# 346832_005-LP1-16S-0101  0.00       None         None0.00.0
# ...                       ...        ...                ...
# 346832_939-LP1-16S-1148  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
# 346832_940-LP1-16S-1149  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
# 346832_941-LP1-16S-1150  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
# 346832_942-LP1-16S-1151  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
# 346832_943-LP1-16S-1152  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
#
#                                                 Sample
# sample-id
# 346832_001-LP1-16S-0097                    DNA18-pos-1
# 346832_002-LP1-16S-0098   Must-20-AUG-2022-gt48-Block2
# 346832_003-LP1-16S-0099   Must-20-AUG-2022-gt48-Block1
# 346832_004-LP1-16S-0100  Must-27-AUG-2022-gt110-Block1
# 346832_005-LP1-16S-0101  Must-27-AUG-2022-gt147-Block2
# ...                                                ...
# 346832_939-LP1-16S-1148  Must-27-AUG-2022-gt110-Block1
# 346832_940-LP1-16S-1149  Must-27-AUG-2022-gt147-Block2
# 346832_941-LP1-16S-1150   Must-20-AUG-2022-gt64-Block2
# 346832_942-LP1-16S-1151    Must-20-AUG-2022-gt5-Block2
# 346832_943-LP1-16S-1152  Must-20-AUG-2022-gt120-Block1
#
# [128 rows x 11 columns]

# %%
formula = 'Sample * PNAs' 

beta_metrics = ['bray_curtis', 'jaccard']


for m in beta_metrics:
    adonis_res, = q2d.actions.adonis(
        distance_matrix=core_div_dict[m + '_distance_matrix'],
        metadata=md,
        formula=formula,
        n_jobs=threads)
    adonis_res.save(output_dir + 'adonis_{0}.qzv'.format(m))
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /scratch/lfloerl/tmpdata/tmp5xnno9_a/dm.tsv /scratch/lfloerl/tmpdata/tmp5xnno9_a/md.tsv Sample + pPNA + mPNA 999 5 /scratch/lfloerl/tmpdata/qiime2-temp-7bxo5q18/adonis.tsv
#
# R version 4.2.2 (2022-10-31)
# Lade nötiges Paket: permute
# Lade nötiges Paket: lattice
# This is vegan 2.6-4
# 'adonis' will be deprecated: use 'adonis2' instead
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: run_adonis.R /scratch/lfloerl/tmpdata/tmp6rwmg1xl/dm.tsv /scratch/lfloerl/tmpdata/tmp6rwmg1xl/md.tsv Sample + pPNA + mPNA 999 5 /scratch/lfloerl/tmpdata/qiime2-temp-090oz6yr/adonis.tsv
#
# R version 4.2.2 (2022-10-31)
# Lade nötiges Paket: permute
# Lade nötiges Paket: lattice
# This is vegan 2.6-4
# 'adonis' will be deprecated: use 'adonis2' instead

# %%
Visualization.load(f'{wd}/{output_dir}/adonis_jaccard.qzv')
# Out:
# <visualization: Visualization uuid: eb29eb12-4db5-4b53-8802-806549af43d5>

# %%
Visualization.load(f'{wd}/{output_dir}/adonis_bray_curtis.qzv')
# Out:
# <visualization: Visualization uuid: 24d7f247-585d-43e9-bd73-c1383708b64d>

# %% [markdown]
# <hr>
#
#
# # Appendix: Let's check if PNAs contributed to the reagent contamination

# %%
# %%bash
#
# # classified to feature level
# qiime taxa filter-table \
#   --i-table /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/decontam-table.qza \
#   --i-taxonomy /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/taxonomy.qza \
#   --p-include p__ \
#   --p-exclude Eukaryota,Archaea \
#   --o-filtered-table phylum_filtered_table.qza
#
# qiime feature-table summarize --i-table phylum_filtered_table.qza --o-visualization phylum_filtered_table.qzv
#
# # remove contaminants
# qiime taxa filter-table \
#   --i-table phylum_filtered_table.qza \
#   --i-taxonomy /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/taxonomy.qza \
#   --p-exclude Alcaligenaceae,Caulobacteraceae,Comamonadaceae,Pedobacter,Escherichia-Shigella \
#   --o-filtered-table contaminants_filtered_table.qza
#
# qiime feature-table summarize --i-table contaminants_filtered_table.qza --o-visualization contaminants_filtered_table.qzv
#
# # remove chloroplasts, mitochondria
# qiime taxa filter-table \
#   --i-table contaminants_filtered_table.qza \
#   --i-taxonomy /home/lfloerl/cloud/lfloerl/RxCS_FGCZ/artifacts/16S/taxonomy.qza \
#   --p-exclude mitochondria,chloroplast \
#   --o-filtered-table ChloroMito_filtered_table.qza
#
# qiime feature-table summarize --i-table ChloroMito_filtered_table.qza --o-visualization ChloroMito_filtered_table.qzv
# Out:
# Saved FeatureTable[Frequency] to: phylum_filtered_table.qza
# Saved Visualization to: phylum_filtered_table.qzv
# Saved FeatureTable[Frequency] to: contaminants_filtered_table.qza
# Saved Visualization to: contaminants_filtered_table.qzv
# Saved FeatureTable[Frequency] to: ChloroMito_filtered_table.qza
# Saved Visualization to: ChloroMito_filtered_table.qzv

# %%
# !qiime tools export --input-path ChloroMito_filtered_table.qzv --output-path ChloroMito_filtered_table
# !qiime tools export --input-path contaminants_filtered_table.qzv --output-path contaminants_filtered_table
# !qiime tools export --input-path phylum_filtered_table.qzv --output-path phylum_filtered_table
# Out:
# Exported ChloroMito_filtered_table.qzv as Visualization to directory ChloroMito_filtered_table
# Exported contaminants_filtered_table.qzv as Visualization to directory contaminants_filtered_table
# Exported phylum_filtered_table.qzv as Visualization to directory phylum_filtered_table

# %%
def extract_frequency_data(folder_name):
    """
    Extracts sample frequency data from an HTML file in a specified folder.

    Parameters:
    folder_name (str): The name of the folder containing the 'sample-frequency-detail.html' file.

    Returns:
    pd.DataFrame: A DataFrame indexed by Sample_ID with a column for the specified folder's Frequency.
    """
    file_path = os.path.join(folder_name, 'sample-frequency-detail.html')
    
    # Load the HTML file
    with open(file_path, 'r') as file:
        soup = BeautifulSoup(file, 'lxml')

    # Find the <script> tag with type="application/json" and id="table-data"
    script_tag = soup.find('script', type='application/json', id='table-data')

    # Check if the script tag was found
    if script_tag:
        # Extract the JSON content from the <script> tag
        json_data = json.loads(script_tag.string)
        
        # Convert the JSON data to a Pandas DataFrame
        filtered_reads = pd.DataFrame(list(json_data.items()), columns=['Sample_ID', folder_name])
        
        # Convert the folder's frequency column to numeric
        filtered_reads[folder_name] = filtered_reads[folder_name].str.replace(',', '').astype(int)
        
        # Set Sample_ID as the index
        filtered_reads.set_index('Sample_ID', inplace=True)
        
        return filtered_reads
    else:
        print(f"No script tag with type 'application/json' found in {file_path}.")
        return pd.DataFrame()  # Return an empty DataFrame if no data is found

# List of folders to process
folder_names = ['phylum_filtered_table', 'contaminants_filtered_table', 'ChloroMito_filtered_table']

# Initialize an empty DataFrame to store all results
all_data = pd.DataFrame()

# Loop through each folder and merge the results into a single DataFrame
for folder in folder_names:
    df = extract_frequency_data(folder)
    if not df.empty:
        if all_data.empty:
            all_data = df
        else:
            all_data = all_data.join(df, how='outer')

# %%
# Calculate percentage of reads lost in contaminants_filtered_table
all_data['contaminants_filtered_table_percentage'] = (
    (all_data['contaminants_filtered_table'] / all_data['phylum_filtered_table']) * 100
)

# Calculate percentage of reads conserved in ChloroMito_filtered_table
all_data['ChloroMito_filtered_table_percentage'] = (
    (all_data['ChloroMito_filtered_table'] / all_data['phylum_filtered_table']) * 100
)

all_data.head()
# Out:
#                          phylum_filtered_table  contaminants_filtered_table  \
# Sample_ID
# 346832_001-LP1-16S-0097                 668672                     563316.0
# 346832_002-LP1-16S-0098                 764294                     688882.0
# 346832_003-LP1-16S-0099                 878608                     835291.0
# 346832_004-LP1-16S-0100                 378428                      25262.0
# 346832_005-LP1-16S-0101                 719925                     590457.0
#
#                          ChloroMito_filtered_table  \
# Sample_ID
# 346832_001-LP1-16S-0097                   563128.0
# 346832_002-LP1-16S-0098                     2851.0
# 346832_003-LP1-16S-0099                      595.0
# 346832_004-LP1-16S-0100                      625.0
# 346832_005-LP1-16S-0101                     1189.0
#
#                          contaminants_filtered_table_percentage  \
# Sample_ID
# 346832_001-LP1-16S-0097                               84.243994
# 346832_002-LP1-16S-0098                               90.133116
# 346832_003-LP1-16S-0099                               95.069815
# 346832_004-LP1-16S-0100                                6.675510
# 346832_005-LP1-16S-0101                               82.016460
#
#                          ChloroMito_filtered_table_percentage
# Sample_ID
# 346832_001-LP1-16S-0097                             84.215879
# 346832_002-LP1-16S-0098                              0.373024
# 346832_003-LP1-16S-0099                              0.067721
# 346832_004-LP1-16S-0100                              0.165157
# 346832_005-LP1-16S-0101                              0.165156

# %%
# this is the metadata we use 
md_bac = pd.read_csv('/home/lfloerl/RxCS/Metadata/16S_PNA-test.csv', sep='\t', index_col=0)
md_bac.head()
# Out:
#                                                         Sample_ID   Plate  \
# ID
# 346832_018-LP1-16S-0114     Must-20-AUG-2022-gt48-Block2_mPNA_0.5  P2_PNA
# 346832_083-LP1-16S-0179    Must-20-AUG-2022-gt48-Block1_pPNA_1.25  P2_PNA
# 346832_922-LP1-16S-1131  Must-20-AUG-2022-gt48-Block1_m+pPNA_0.75     P12
# 346832_619-LP1-16S-0779              Must-20-AUG-2022-gt48-Block1      P9
# 346832_067-LP1-16S-0163    Must-20-AUG-2022-gt48-Block1_pPNA_0.75  P2_PNA
#
#                         Position DNA_extraction_plate  Conc_Bac_30X PNA_test  \
# ID
# 346832_018-LP1-16S-0114      B03                  NaN      2.103733      yes
# 346832_083-LP1-16S-0179      C11                  NaN      7.106294      yes
# 346832_922-LP1-16S-1131      C10                DNA23     11.792798      yes
# 346832_619-LP1-16S-0779      C02                DNA18      1.188433      yes
# 346832_067-LP1-16S-0163      C09                  NaN      2.343575      yes
#
#                         PNAs  mPNA  pPNA    Year  ...               Block  \
# ID                                                ...
# 346832_018-LP1-16S-0114  yes  0.50  0.00  2022.0  ...     Block2_mPNA_0.5
# 346832_083-LP1-16S-0179  yes  0.00  1.25  2022.0  ...    Block1_pPNA_1.25
# 346832_922-LP1-16S-1131  yes  0.75  0.75  2022.0  ...  Block1_m+pPNA_0.75
# 346832_619-LP1-16S-0779  yes  0.50  0.50  2022.0  ...              Block1
# 346832_067-LP1-16S-0163  yes  0.00  0.75  2022.0  ...    Block1_pPNA_0.75
#
#                               Block_no GT_numb Average_Brix  \
# ID
# 346832_018-LP1-16S-0114     2_mPNA_0.5    48.0    23.933333
# 346832_083-LP1-16S-0179    1_pPNA_1.25    48.0    24.633333
# 346832_922-LP1-16S-1131  1_m+pPNA_0.75    48.0    23.100000
# 346832_619-LP1-16S-0779              1    48.0    23.400000
# 346832_067-LP1-16S-0163    1_pPNA_0.75    48.0    21.400000
#
#                          Average_Cluster_Weight  Genotype  Berry_Color  \
# ID
# 346832_018-LP1-16S-0114               43.333333      48.0          Red
# 346832_083-LP1-16S-0179              147.666667      48.0          Red
# 346832_922-LP1-16S-1131              142.333333      48.0          Red
# 346832_619-LP1-16S-0779               78.000000      48.0          Red
# 346832_067-LP1-16S-0163               87.000000      48.0          Red
#
#                            PNA_mix    PNA_composition  \
# ID
# 346832_018-LP1-16S-0114       mPNA         mPNA0.50.0
# 346832_083-LP1-16S-0179       pPNA        pPNA0.01.25
# 346832_922-LP1-16S-1131  mPNA+pPNA  mPNA+pPNA0.750.75
# 346832_619-LP1-16S-0779  mPNA+pPNA    mPNA+pPNA0.50.5
# 346832_067-LP1-16S-0163       pPNA        pPNA0.00.75
#
#                                                Sample
# ID
# 346832_018-LP1-16S-0114  Must-20-AUG-2022-gt48-Block2
# 346832_083-LP1-16S-0179  Must-20-AUG-2022-gt48-Block1
# 346832_922-LP1-16S-1131  Must-20-AUG-2022-gt48-Block1
# 346832_619-LP1-16S-0779  Must-20-AUG-2022-gt48-Block1
# 346832_067-LP1-16S-0163  Must-20-AUG-2022-gt48-Block1
#
# [5 rows x 22 columns]

# %%
merged_df = pd.merge(all_data, md_bac[['PNAs', 'mPNA', 'pPNA', 'PNA_mix','PNA_composition','Sample']], left_index=True, right_index=True, how='inner')
merged_df
# Out:
#                          phylum_filtered_table  contaminants_filtered_table  \
# 346832_001-LP1-16S-0097                 668672                     563316.0
# 346832_002-LP1-16S-0098                 764294                     688882.0
# 346832_003-LP1-16S-0099                 878608                     835291.0
# 346832_004-LP1-16S-0100                 378428                      25262.0
# 346832_005-LP1-16S-0101                 719925                     590457.0
# ...                                        ...                          ...
# 346832_939-LP1-16S-1148                 535981                        930.0
# 346832_940-LP1-16S-1149                 205112                      13339.0
# 346832_941-LP1-16S-1150                    592                        374.0
# 346832_942-LP1-16S-1151                   4279                        393.0
# 346832_943-LP1-16S-1152                    564                        339.0
#
#                          ChloroMito_filtered_table  \
# 346832_001-LP1-16S-0097                   563128.0
# 346832_002-LP1-16S-0098                     2851.0
# 346832_003-LP1-16S-0099                      595.0
# 346832_004-LP1-16S-0100                      625.0
# 346832_005-LP1-16S-0101                     1189.0
# ...                                            ...
# 346832_939-LP1-16S-1148                      733.0
# 346832_940-LP1-16S-1149                     1326.0
# 346832_941-LP1-16S-1150                      180.0
# 346832_942-LP1-16S-1151                       89.0
# 346832_943-LP1-16S-1152                      138.0
#
#                          contaminants_filtered_table_percentage  \
# 346832_001-LP1-16S-0097                               84.243994
# 346832_002-LP1-16S-0098                               90.133116
# 346832_003-LP1-16S-0099                               95.069815
# 346832_004-LP1-16S-0100                                6.675510
# 346832_005-LP1-16S-0101                               82.016460
# ...                                                         ...
# 346832_939-LP1-16S-1148                                0.173514
# 346832_940-LP1-16S-1149                                6.503276
# 346832_941-LP1-16S-1150                               63.175676
# 346832_942-LP1-16S-1151                                9.184389
# 346832_943-LP1-16S-1152                               60.106383
#
#                          ChloroMito_filtered_table_percentage PNAs  mPNA  \
# 346832_001-LP1-16S-0097                             84.215879   no  0.00
# 346832_002-LP1-16S-0098                              0.373024   no  0.00
# 346832_003-LP1-16S-0099                              0.067721   no  0.00
# 346832_004-LP1-16S-0100                              0.165157   no  0.00
# 346832_005-LP1-16S-0101                              0.165156   no  0.00
# ...                                                       ...  ...   ...
# 346832_939-LP1-16S-1148                              0.136759  yes  1.25
# 346832_940-LP1-16S-1149                              0.646476  yes  1.25
# 346832_941-LP1-16S-1150                             30.405405  yes  1.25
# 346832_942-LP1-16S-1151                              2.079925  yes  1.25
# 346832_943-LP1-16S-1152                             24.468085  yes  1.25
#
#                          pPNA    PNA_mix    PNA_composition  \
# 346832_001-LP1-16S-0097  0.00       None         None0.00.0
# 346832_002-LP1-16S-0098  0.00       None         None0.00.0
# 346832_003-LP1-16S-0099  0.00       None         None0.00.0
# 346832_004-LP1-16S-0100  0.00       None         None0.00.0
# 346832_005-LP1-16S-0101  0.00       None         None0.00.0
# ...                       ...        ...                ...
# 346832_939-LP1-16S-1148  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
# 346832_940-LP1-16S-1149  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
# 346832_941-LP1-16S-1150  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
# 346832_942-LP1-16S-1151  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
# 346832_943-LP1-16S-1152  1.25  mPNA+pPNA  mPNA+pPNA1.251.25
#
#                                                 Sample
# 346832_001-LP1-16S-0097                    DNA18-pos-1
# 346832_002-LP1-16S-0098   Must-20-AUG-2022-gt48-Block2
# 346832_003-LP1-16S-0099   Must-20-AUG-2022-gt48-Block1
# 346832_004-LP1-16S-0100  Must-27-AUG-2022-gt110-Block1
# 346832_005-LP1-16S-0101  Must-27-AUG-2022-gt147-Block2
# ...                                                ...
# 346832_939-LP1-16S-1148  Must-27-AUG-2022-gt110-Block1
# 346832_940-LP1-16S-1149  Must-27-AUG-2022-gt147-Block2
# 346832_941-LP1-16S-1150   Must-20-AUG-2022-gt64-Block2
# 346832_942-LP1-16S-1151    Must-20-AUG-2022-gt5-Block2
# 346832_943-LP1-16S-1152  Must-20-AUG-2022-gt120-Block1
#
# [128 rows x 11 columns]

# %%
merged_df.index.name = 'sample-id'
merged_df.to_csv('/home/lfloerl/RxCS/Metadata/16S_PNA-test-withLoss.tsv', sep='\t', index=1)

# %%
# Melt the DataFrame to long format
df_melted = merged_df.melt(id_vars=['PNA_composition'], 
                           value_vars=['phylum_filtered_table', 'contaminants_filtered_table', 'ChloroMito_filtered_table'],
                           var_name='Filtering_Step', value_name='Value')

# Create a custom color palette
base_color = 'blue'  # Base color for all lines
highlight_color = 'orange'  # Highlight color for 'None0.00.0'

# Get unique PNA_composition values
unique_pna = df_melted['PNA_composition'].unique()

# Generate a palette where all lines except 'None0.00.0' have the same base color with different shadings
palette = {pna: highlight_color if pna == 'None0.00.0' else base_color for pna in unique_pna}

# Plot the data with a line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_melted, x='Filtering_Step', y='Value', hue='PNA_composition', ci='sd', palette=palette, linewidth=2)

# Customize the plot
plt.title('Read Counts Over Different Filtering Steps by PNA Composition')
plt.xlabel('Filtering Step')
plt.ylabel('Read Count')
plt.xticks(rotation=45)

# Move the legend to the right outside the graph
plt.legend(title='PNA Composition', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /scratch/lfloerl/tmpdata/ipykernel_618850/298591712.py:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(data=df_melted, x='Filtering_Step', y='Value', hue='PNA_composition', ci='sd', palette=palette, linewidth=2)

# %%
# Categorize PNA_composition into 'None0.00.0' and 'Other', and create a new column
merged_df['PNA_Category'] = merged_df['PNA_composition'].apply(lambda x: 'None0.00.0' if x == 'None0.00.0' else 'Other')

# Separate data based on categories
none_pna = merged_df[merged_df['PNA_Category'] == 'None0.00.0']['contaminants_filtered_table_percentage']
other_pna = merged_df[merged_df['PNA_Category'] == 'Other']['contaminants_filtered_table_percentage']

# Perform t-test
t_stat, p_value = stats.ttest_ind(none_pna, other_pna, nan_policy='omit')

print(f"T-test result: t-statistic = {t_stat:.3f}, p-value = {p_value:.3f}")
# Out:
# T-test result: t-statistic = 2.087, p-value = 0.037

# %%
corr_df = merged_df[['contaminants_filtered_table_percentage', 'mPNA', 'pPNA','Sample']]
corr_df.head()
# Out:
#                          contaminants_filtered_table_percentage  mPNA  pPNA  \
# Sample_ID
# 346832_001-LP1-16S-0097                               84.243994   0.0   0.0
# 346832_002-LP1-16S-0098                               90.133116   0.0   0.0
# 346832_003-LP1-16S-0099                               95.069815   0.0   0.0
# 346832_004-LP1-16S-0100                                6.675510   0.0   0.0
# 346832_005-LP1-16S-0101                               82.016460   0.0   0.0
#
#                                                 Sample
# Sample_ID
# 346832_001-LP1-16S-0097                    DNA18-pos-1
# 346832_002-LP1-16S-0098   Must-20-AUG-2022-gt48-Block2
# 346832_003-LP1-16S-0099   Must-20-AUG-2022-gt48-Block1
# 346832_004-LP1-16S-0100  Must-27-AUG-2022-gt110-Block1
# 346832_005-LP1-16S-0101  Must-27-AUG-2022-gt147-Block2

# %%
# Calculate Pearson correlation matrix
corr_matrix = corr_df.corr(method='spearman')

# Plot the heatmap
plt.figure(figsize=(3,3))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f', linewidths=0.5)
plt.title('Spearman Correlation Heatmap')
plt.show()
# Out:
# /scratch/lfloerl/tmpdata/ipykernel_618850/1007663749.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = corr_df.corr(method='spearman')

# %%
# Calculate Pearson correlation matrix
corr_matrix = corr_df.corr(method='pearson')

# Plot the heatmap
plt.figure(figsize=(3,3))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f', linewidths=0.5)
plt.title('Bacteria: Pearson Correlation Heatmap')
plt.show()
# Out:
# /scratch/lfloerl/tmpdata/ipykernel_437768/1101071638.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = corr_df.corr(method='pearson')

# %%
permanova_df = merged_df[['contaminants_filtered_table_percentage','Sample','PNA_composition']]
permanova_df.head()
# Out:
#                          contaminants_filtered_table_percentage  \
# Sample_ID
# 346832_001-LP1-16S-0097                               84.243994
# 346832_002-LP1-16S-0098                               90.133116
# 346832_003-LP1-16S-0099                               95.069815
# 346832_004-LP1-16S-0100                                6.675510
# 346832_005-LP1-16S-0101                               82.016460
#
#                                                 Sample PNA_composition
# Sample_ID
# 346832_001-LP1-16S-0097                    DNA18-pos-1      None0.00.0
# 346832_002-LP1-16S-0098   Must-20-AUG-2022-gt48-Block2      None0.00.0
# 346832_003-LP1-16S-0099   Must-20-AUG-2022-gt48-Block1      None0.00.0
# 346832_004-LP1-16S-0100  Must-27-AUG-2022-gt110-Block1      None0.00.0
# 346832_005-LP1-16S-0101  Must-27-AUG-2022-gt147-Block2      None0.00.0

# %%
# Create a distance matrix based on contaminants_filtered_table_percentage
distance_matrix = squareform(pdist(permanova_df[['contaminants_filtered_table_percentage']], metric='euclidean'))

# Perform PERMANOVA using statsmodels for Sample
permanova_df['Sample_encoded'] = permanova_df['Sample'].astype('category').cat.codes
model_sample = ols('contaminants_filtered_table_percentage ~ C(Sample_encoded)', data=permanova_df).fit()
anova_table_sample = anova_lm(model_sample, typ=2)
# Calculate R^2
ss_model = anova_table_sample['sum_sq']['C(Sample_encoded)']
ss_total = ss_model + anova_table_sample['sum_sq']['Residual']
r_squared = ss_model / ss_total

print("PERMANOVA results for Sample:")
print(anova_table_sample)
print(f"R^2: {r_squared:.3f}")


# Perform PERMANOVA using statsmodels for PNA_composition
permanova_df['PNA_composition_encoded'] = permanova_df['PNA_composition'].astype('category').cat.codes
model_pna = ols('contaminants_filtered_table_percentage ~ C(PNA_composition_encoded)', data=permanova_df).fit()
anova_table_pna = anova_lm(model_pna, typ=2)
# Calculate R^2
ss_model_pna = anova_table_pna['sum_sq']['C(PNA_composition_encoded)']
ss_total_pna = ss_model_pna + anova_table_pna['sum_sq']['Residual']
r_squared_pna = ss_model_pna / ss_total_pna


print("\nPERMANOVA results for PNA_composition:")
print(anova_table_pna)
print(f"R^2: {r_squared_pna:.3f}")
# Out:
# PERMANOVA results for Sample:
#                          sum_sq     df         F        PR(>F)
# C(Sample_encoded)  1.115232e+05    8.0  8.805648  1.163603e-11
# Residual           1.469136e+06  928.0       NaN           NaN
# R^2: 0.071
#
# PERMANOVA results for PNA_composition:
#                                   sum_sq     df         F   PR(>F)
# C(PNA_composition_encoded)  6.455708e+04   16.0  2.448404  0.00122
# Residual                    1.516102e+06  920.0       NaN      NaN
# R^2: 0.041
# /scratch/lfloerl/tmpdata/ipykernel_618850/3445477355.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   permanova_df['Sample_encoded'] = permanova_df['Sample'].astype('category').cat.codes
# /scratch/lfloerl/tmpdata/ipykernel_618850/3445477355.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   permanova_df['PNA_composition_encoded'] = permanova_df['PNA_composition'].astype('category').cat.codes

# %%
permanova_df
# Out:
#                          contaminants_filtered_table_percentage  \
# Sample_ID
# 346832_001-LP1-16S-0097                               84.243994
# 346832_002-LP1-16S-0098                               90.133116
# 346832_003-LP1-16S-0099                               95.069815
# 346832_004-LP1-16S-0100                                6.675510
# 346832_005-LP1-16S-0101                               82.016460
# ...                                                         ...
# 346832_939-LP1-16S-1148                                0.173514
# 346832_940-LP1-16S-1149                                6.503276
# 346832_941-LP1-16S-1150                               63.175676
# 346832_942-LP1-16S-1151                                9.184389
# 346832_943-LP1-16S-1152                               60.106383
#
#                                                 Sample    PNA_composition
# Sample_ID
# 346832_001-LP1-16S-0097                    DNA18-pos-1         None0.00.0
# 346832_002-LP1-16S-0098   Must-20-AUG-2022-gt48-Block2         None0.00.0
# 346832_003-LP1-16S-0099   Must-20-AUG-2022-gt48-Block1         None0.00.0
# 346832_004-LP1-16S-0100  Must-27-AUG-2022-gt110-Block1         None0.00.0
# 346832_005-LP1-16S-0101  Must-27-AUG-2022-gt147-Block2         None0.00.0
# ...                                                ...                ...
# 346832_939-LP1-16S-1148  Must-27-AUG-2022-gt110-Block1  mPNA+pPNA1.251.25
# 346832_940-LP1-16S-1149  Must-27-AUG-2022-gt147-Block2  mPNA+pPNA1.251.25
# 346832_941-LP1-16S-1150   Must-20-AUG-2022-gt64-Block2  mPNA+pPNA1.251.25
# 346832_942-LP1-16S-1151    Must-20-AUG-2022-gt5-Block2  mPNA+pPNA1.251.25
# 346832_943-LP1-16S-1152  Must-20-AUG-2022-gt120-Block1  mPNA+pPNA1.251.25
#
# [937 rows x 3 columns]

# %% [markdown]
# ### NESTED PERMANOVA

# %%
# !qiime metadata distance-matrix --m-metadata-file /home/lfloerl/RxCS/Metadata/16S_PNA-test-withLoss.tsv --m-metadata-column 'contaminants_filtered_table_percentage' --o-distance-matrix contaminants-distance-matrix.qza
# Out:
# Saved DistanceMatrix to: contaminants-distance-matrix.qza

# %%
# %%bash
#
# qiime diversity adonis \
#     --i-distance-matrix contaminants-distance-matrix.qza \
#     --m-metadata-file /home/lfloerl/RxCS/Metadata/16S_PNA-test-withLoss.tsv \
#     --p-formula 'Sample*PNA_composition' \
#     --p-n-jobs 5 \
#     --o-visualization adonis-contaminations.qzv
# Out:
# Saved Visualization to: adonis-contaminations.qzv

# %%
Visualization.load('adonis-contaminations.qzv')
# Out:
# <visualization: Visualization uuid: 9d0e6833-f7ab-41ee-b981-1fea0642641c>
